# %% [markdown]
# <a href="https://colab.research.google.com/github/sh-0620/dacon-recommendation-system/blob/main/tf-idf_word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import warnings

from tensorflow.keras.layers import Input, Embedding, Flatten, Dot, Dense, Concatenate
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/MyDrive/데이콘/기사추천시스템/open/'

# %%
article_info = pd.read_csv(data_path + 'article_info.csv')

# %%
article_info #기사 정보(userid = 기사 작성자)
# Out:
#          articleID                                              Title  \
# 0     ARTICLE_0000                       19 Tips For Everyday Git Use
# 1     ARTICLE_0001  Intel buys computer vision startup Itseez to i...
# 2     ARTICLE_0002       Practical End-to-End Testing with Protractor
# 3     ARTICLE_0003  Corporate venture growth in Brazil is another ...
# 4     ARTICLE_0004  Cross-channel user experiences with Drupal (aw...
# ...            ...                                                ...
# 3003  ARTICLE_3003  Como consumir conteúdo de qualidade em iOS - C...
# 3004  ARTICLE_3004                             Aurelia 1.0 is Here!!!
# 3005  ARTICLE_3005  Lessons from converting an app to 100% Kotlin ...
# 3006  ARTICLE_3006  ITA está oferecendo 10 cursos gratuitos a dist...
# 3007  ARTICLE_3007            Analytics startup Amplitude raises $15M
#
#                                                 Content Format Language  \
# 0     I've been using git full time for the past 4 y...   HTML       en
# 1     Intel has acquired computer vision and machine...   HTML       en
# 2     One of the reasons AngularJS is so great to wo...   HTML       en
# 3     Despite recent positive news and a renewed int...   HTML       en
# 4     Last year around this time, I wrote that The B...   HTML       en
# ...                                                 ...    ...      ...
# 3003  Quando iniciei minha jornada em Swift, saindo ...   HTML       pt
# 3004  It's been an amazing journey to get here and i...   HTML       en
# 3005  This is part one in a series of posts about Ko...   HTML       en
# 3006  O Instituto Tecnológico de Aeronáutica (ITA) ,...   HTML       pt
# 3007  Amplitude announced this morning that it has r...   HTML       en
#
#          userID userCountry userRegion
# 0     USER_0683         NaN        NaN
# 1     USER_1129         NaN        NaN
# 2     USER_0256         NaN        NaN
# 3     USER_1304         NaN        NaN
# 4     USER_0336         NaN        NaN
# ...         ...         ...        ...
# 3003  USER_0882          BR         MG
# 3004  USER_0220         NaN        NaN
# 3005  USER_1010          BR         SP
# 3006  USER_1210         NaN        NaN
# 3007  USER_0067         NaN        NaN
#
# [3008 rows x 8 columns]

# %%
article_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3008 entries, 0 to 3007
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   articleID    3008 non-null   object
#  1   Title        3008 non-null   object
#  2   Content      3008 non-null   object
#  3   Format       3008 non-null   object
#  4   Language     3008 non-null   object
#  5   userID       3008 non-null   object
#  6   userCountry  659 non-null    object
#  7   userRegion   657 non-null    object
# dtypes: object(8)
# memory usage: 188.1+ KB

# %%
article_info
# Out:
#          articleID                                              Title  \
# 0     ARTICLE_0000                       19 Tips For Everyday Git Use
# 1     ARTICLE_0001  Intel buys computer vision startup Itseez to i...
# 2     ARTICLE_0002       Practical End-to-End Testing with Protractor
# 3     ARTICLE_0003  Corporate venture growth in Brazil is another ...
# 4     ARTICLE_0004  Cross-channel user experiences with Drupal (aw...
# ...            ...                                                ...
# 3003  ARTICLE_3003  Como consumir conteúdo de qualidade em iOS - C...
# 3004  ARTICLE_3004                             Aurelia 1.0 is Here!!!
# 3005  ARTICLE_3005  Lessons from converting an app to 100% Kotlin ...
# 3006  ARTICLE_3006  ITA está oferecendo 10 cursos gratuitos a dist...
# 3007  ARTICLE_3007            Analytics startup Amplitude raises $15M
#
#                                                 Content Format Language  \
# 0     I've been using git full time for the past 4 y...   HTML       en
# 1     Intel has acquired computer vision and machine...   HTML       en
# 2     One of the reasons AngularJS is so great to wo...   HTML       en
# 3     Despite recent positive news and a renewed int...   HTML       en
# 4     Last year around this time, I wrote that The B...   HTML       en
# ...                                                 ...    ...      ...
# 3003  Quando iniciei minha jornada em Swift, saindo ...   HTML       pt
# 3004  It's been an amazing journey to get here and i...   HTML       en
# 3005  This is part one in a series of posts about Ko...   HTML       en
# 3006  O Instituto Tecnológico de Aeronáutica (ITA) ,...   HTML       pt
# 3007  Amplitude announced this morning that it has r...   HTML       en
#
#          userID userCountry userRegion
# 0     USER_0683         NaN        NaN
# 1     USER_1129         NaN        NaN
# 2     USER_0256         NaN        NaN
# 3     USER_1304         NaN        NaN
# 4     USER_0336         NaN        NaN
# ...         ...         ...        ...
# 3003  USER_0882          BR         MG
# 3004  USER_0220         NaN        NaN
# 3005  USER_1010          BR         SP
# 3006  USER_1210         NaN        NaN
# 3007  USER_0067         NaN        NaN
#
# [3008 rows x 8 columns]

# %%
view_log = pd.read_csv(data_path + 'view_log.csv')

# %%
view_log #사용자-기사 데이터
# Out:
#           userID     articleID userRegion userCountry
# 0      USER_0000  ARTICLE_0661         NY          US
# 1      USER_0000  ARTICLE_2316         NY          US
# 2      USER_0000  ARTICLE_1345         NY          US
# 3      USER_0000  ARTICLE_1089         NY          US
# 4      USER_0000  ARTICLE_1484         NY          US
# ...          ...           ...        ...         ...
# 42712  USER_1420  ARTICLE_0682         SP          BR
# 42713  USER_1420  ARTICLE_2179         SP          BR
# 42714  USER_1420  ARTICLE_1848         SP          BR
# 42715  USER_1420  ARTICLE_0030         SP          BR
# 42716  USER_1420  ARTICLE_2423         SP          BR
#
# [42717 rows x 4 columns]

# %%
view_log.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42717 entries, 0 to 42716
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   userID       42717 non-null  object
#  1   articleID    42717 non-null  object
#  2   userRegion   42717 non-null  object
#  3   userCountry  42717 non-null  object
# dtypes: object(4)
# memory usage: 1.3+ MB

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import TruncatedSVD

# %%
# TF-IDF 벡터화
tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_features=5000) #stop_words='english'는 영어 불용어를 제거하고, max_features=5000는 최대 5000개의 단어 특성을 사용한다는 의미입니다.
tfidf_matrix = tfidf_vectorizer.fit_transform(article_info['Title'])

# 코사인 유사도 계산
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
def get_personalized_recommendations(user_id, cosine_sim=cosine_sim, articles_df=article_info):
    # 사용자가 읽은 기사 목록 가져오기
    user_articles = view_log[view_log['userID'] == user_id]['articleID'].tolist()

    # 사용자가 읽은 기사의 인덱스 가져오기
    article_indices = article_info[article_info['articleID'].isin(user_articles)].index.tolist()

    # 유사도 점수 합산
    sim_scores = cosine_sim[article_indices].sum(axis=0)

    # 유사도 점수를 기준으로 기사 정렬
    ranked_indices = sim_scores.argsort()[::-1]

    # 상위 5개 기사 추천
    recommended_article_indices = ranked_indices[:5]

    return articles_df.iloc[recommended_article_indices]

# %%
get_personalized_recommendations('USER_1420')['articleID'].values
# Out:
# array(['ARTICLE_1351', 'ARTICLE_1891', 'ARTICLE_1788', 'ARTICLE_0445',
#        'ARTICLE_2409'], dtype=object)

# %%
recommendations = []
for idx, user in enumerate(view_log.userID.unique()):
    recommendations.append([user, get_personalized_recommendations(user).articleID.values])

# %%
recommendations
# Out:
# [['USER_0000',
#   array(['ARTICLE_2441', 'ARTICLE_1270', 'ARTICLE_1809', 'ARTICLE_2721',
#          'ARTICLE_1891'], dtype=object)],
#  ['USER_0001',
#   array(['ARTICLE_2493', 'ARTICLE_2311', 'ARTICLE_2087', 'ARTICLE_1213',
#          'ARTICLE_2406'], dtype=object)],
#  ['USER_0002',
#   array(['ARTICLE_1910', 'ARTICLE_2782', 'ARTICLE_2879', 'ARTICLE_1092',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0003',
#   array(['ARTICLE_0958', 'ARTICLE_1092', 'ARTICLE_2115', 'ARTICLE_2879',
#          'ARTICLE_0744'], dtype=object)],
#  ['USER_0004',
#   array(['ARTICLE_0690', 'ARTICLE_0912', 'ARTICLE_1018', 'ARTICLE_2879',
#          'ARTICLE_1788'], dtype=object)],
#  ['USER_0005',
#   array(['ARTICLE_0931', 'ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_0968',
#          'ARTICLE_1076'], dtype=object)],
#  ['USER_0006',
#   array(['ARTICLE_0758', 'ARTICLE_0586', 'ARTICLE_1624', 'ARTICLE_1449',
#          'ARTICLE_1058'], dtype=object)],
#  ['USER_0007',
#   array(['ARTICLE_0265', 'ARTICLE_0553', 'ARTICLE_1673', 'ARTICLE_1162',
#          'ARTICLE_0712'], dtype=object)],
#  ['USER_0008',
#   array(['ARTICLE_2879', 'ARTICLE_2592', 'ARTICLE_1788', 'ARTICLE_1018',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0009',
#   array(['ARTICLE_0590', 'ARTICLE_1587', 'ARTICLE_2868', 'ARTICLE_2199',
#          'ARTICLE_2841'], dtype=object)],
#  ['USER_0010',
#   array(['ARTICLE_2409', 'ARTICLE_1351', 'ARTICLE_2879', 'ARTICLE_1092',
#          'ARTICLE_0744'], dtype=object)],
#  ['USER_0011',
#   array(['ARTICLE_2782', 'ARTICLE_2879', 'ARTICLE_2921', 'ARTICLE_2576',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0012',
#   array(['ARTICLE_1541', 'ARTICLE_1910', 'ARTICLE_1381', 'ARTICLE_0212',
#          'ARTICLE_0502'], dtype=object)],
#  ['USER_0013',
#   array(['ARTICLE_1523', 'ARTICLE_2259', 'ARTICLE_0706', 'ARTICLE_1177',
#          'ARTICLE_2844'], dtype=object)],
#  ['USER_0014',
#   array(['ARTICLE_2598', 'ARTICLE_2068', 'ARTICLE_0422', 'ARTICLE_1498',
#          'ARTICLE_2991'], dtype=object)],
#  ['USER_0015',
#   array(['ARTICLE_0968', 'ARTICLE_1601', 'ARTICLE_2493', 'ARTICLE_1092',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0016',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_0553',
#          'ARTICLE_2166'], dtype=object)],
#  ['USER_0017',
#   array(['ARTICLE_1351', 'ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_2345',
#          'ARTICLE_1788'], dtype=object)],
#  ['USER_0018',
#   array(['ARTICLE_1159', 'ARTICLE_0476', 'ARTICLE_1693', 'ARTICLE_1108',
#          'ARTICLE_2570'], dtype=object)],
#  ['USER_0019',
#   array(['ARTICLE_1092', 'ARTICLE_1011', 'ARTICLE_2879', 'ARTICLE_0744',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0020',
#   array(['ARTICLE_2455', 'ARTICLE_1133', 'ARTICLE_1682', 'ARTICLE_2722',
#          'ARTICLE_2118'], dtype=object)],
#  ['USER_0021',
#   array(['ARTICLE_1970', 'ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_1743',
#          'ARTICLE_1018'], dtype=object)],
#  ['USER_0022',
#   array(['ARTICLE_2485', 'ARTICLE_0169', 'ARTICLE_0457', 'ARTICLE_1159',
#          'ARTICLE_0079'], dtype=object)],
#  ['USER_0023',
#   array(['ARTICLE_2021', 'ARTICLE_2894', 'ARTICLE_0610', 'ARTICLE_0427',
#          'ARTICLE_0968'], dtype=object)],
#  ['USER_0024',
#   array(['ARTICLE_2782', 'ARTICLE_1824', 'ARTICLE_1982', 'ARTICLE_2684',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0025',
#   array(['ARTICLE_0886', 'ARTICLE_2485', 'ARTICLE_0079', 'ARTICLE_0457',
#          'ARTICLE_0731'], dtype=object)],
#  ['USER_0026',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_1910',
#          'ARTICLE_0803'], dtype=object)],
#  ['USER_0027',
#   array(['ARTICLE_2140', 'ARTICLE_0085', 'ARTICLE_2434', 'ARTICLE_2750',
#          'ARTICLE_2515'], dtype=object)],
#  ['USER_0028',
#   array(['ARTICLE_2879', 'ARTICLE_2782', 'ARTICLE_1092', 'ARTICLE_2668',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0029',
#   array(['ARTICLE_0411', 'ARTICLE_2889', 'ARTICLE_2081', 'ARTICLE_2449',
#          'ARTICLE_0830'], dtype=object)],
#  ['USER_0030',
#   array(['ARTICLE_1541', 'ARTICLE_2052', 'ARTICLE_1910', 'ARTICLE_1092',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0031',
#   array(['ARTICLE_2409', 'ARTICLE_1910', 'ARTICLE_0744', 'ARTICLE_2879',
#          'ARTICLE_2782'], dtype=object)],
#  ['USER_0032',
#   array(['ARTICLE_2087', 'ARTICLE_0118', 'ARTICLE_2958', 'ARTICLE_1408',
#          'ARTICLE_1028'], dtype=object)],
#  ['USER_0033',
#   array(['ARTICLE_1159', 'ARTICLE_1108', 'ARTICLE_0744', 'ARTICLE_2259',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0034',
#   array(['ARTICLE_0535', 'ARTICLE_2045', 'ARTICLE_2490', 'ARTICLE_1624',
#          'ARTICLE_1841'], dtype=object)],
#  ['USER_0035',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_1351',
#          'ARTICLE_0744'], dtype=object)],
#  ['USER_0036',
#   array(['ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_1983', 'ARTICLE_1092',
#          'ARTICLE_1788'], dtype=object)],
#  ['USER_0037',
#   array(['ARTICLE_1413', 'ARTICLE_0838', 'ARTICLE_1252', 'ARTICLE_1092',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0038',
#   array(['ARTICLE_2364', 'ARTICLE_1460', 'ARTICLE_0756', 'ARTICLE_1740',
#          'ARTICLE_1604'], dtype=object)],
#  ['USER_0039',
#   array(['ARTICLE_2592', 'ARTICLE_1824', 'ARTICLE_1443', 'ARTICLE_2879',
#          'ARTICLE_0286'], dtype=object)],
#  ['USER_0040',
#   array(['ARTICLE_1172', 'ARTICLE_0509', 'ARTICLE_1624', 'ARTICLE_0325',
#          'ARTICLE_1213'], dtype=object)],
#  ['USER_0041',
#   array(['ARTICLE_2879', 'ARTICLE_1351', 'ARTICLE_2409', 'ARTICLE_1018',
#          'ARTICLE_0445'], dtype=object)],
#  ['USER_0042',
#   array(['ARTICLE_2126', 'ARTICLE_0445', 'ARTICLE_2052', 'ARTICLE_2473',
#          'ARTICLE_0226'], dtype=object)],
#  ['USER_0043',
#   array(['ARTICLE_0968', 'ARTICLE_0244', 'ARTICLE_2879', 'ARTICLE_1092',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0044',
#   array(['ARTICLE_1092', 'ARTICLE_2274', 'ARTICLE_0938', 'ARTICLE_1413',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0045',
#   array(['ARTICLE_2606', 'ARTICLE_2879', 'ARTICLE_1252', 'ARTICLE_0744',
#          'ARTICLE_0508'], dtype=object)],
#  ['USER_0046',
#   array(['ARTICLE_0033', 'ARTICLE_2967', 'ARTICLE_2313', 'ARTICLE_2309',
#          'ARTICLE_1513'], dtype=object)],
#  ['USER_0047',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_1018',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0048',
#   array(['ARTICLE_0780', 'ARTICLE_0553', 'ARTICLE_2409', 'ARTICLE_1351',
#          'ARTICLE_1108'], dtype=object)],
#  ['USER_0049',
#   array(['ARTICLE_1108', 'ARTICLE_2879', 'ARTICLE_1761', 'ARTICLE_0803',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0050',
#   array(['ARTICLE_2586', 'ARTICLE_1522', 'ARTICLE_1729', 'ARTICLE_1974',
#          'ARTICLE_0208'], dtype=object)],
#  ['USER_0051',
#   array(['ARTICLE_2102', 'ARTICLE_2889', 'ARTICLE_1910', 'ARTICLE_1112',
#          'ARTICLE_1252'], dtype=object)],
#  ['USER_0052',
#   array(['ARTICLE_1498', 'ARTICLE_0038', 'ARTICLE_1108', 'ARTICLE_1159',
#          'ARTICLE_1351'], dtype=object)],
#  ['USER_0053',
#   array(['ARTICLE_1696', 'ARTICLE_2782', 'ARTICLE_2879', 'ARTICLE_1999',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0054',
#   array(['ARTICLE_1108', 'ARTICLE_1498', 'ARTICLE_1159', 'ARTICLE_0038',
#          'ARTICLE_0520'], dtype=object)],
#  ['USER_0055',
#   array(['ARTICLE_0882', 'ARTICLE_0816', 'ARTICLE_2493', 'ARTICLE_2879',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0056',
#   array(['ARTICLE_1384', 'ARTICLE_1499', 'ARTICLE_1933', 'ARTICLE_0251',
#          'ARTICLE_1004'], dtype=object)],
#  ['USER_0057',
#   array(['ARTICLE_2698', 'ARTICLE_0200', 'ARTICLE_1652', 'ARTICLE_1881',
#          'ARTICLE_0902'], dtype=object)],
#  ['USER_0058',
#   array(['ARTICLE_1206', 'ARTICLE_0278', 'ARTICLE_1351', 'ARTICLE_1092',
#          'ARTICLE_2668'], dtype=object)],
#  ['USER_0059',
#   array(['ARTICLE_0352', 'ARTICLE_2868', 'ARTICLE_2045', 'ARTICLE_2991',
#          'ARTICLE_1740'], dtype=object)],
#  ['USER_0060',
#   array(['ARTICLE_0858', 'ARTICLE_2389', 'ARTICLE_0760', 'ARTICLE_2842',
#          'ARTICLE_1046'], dtype=object)],
#  ['USER_0061',
#   array(['ARTICLE_0588', 'ARTICLE_2126', 'ARTICLE_0073', 'ARTICLE_2806',
#          'ARTICLE_0668'], dtype=object)],
#  ['USER_0062',
#   array(['ARTICLE_0958', 'ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_2782',
#          'ARTICLE_0968'], dtype=object)],
#  ['USER_0063',
#   array(['ARTICLE_0926', 'ARTICLE_2782', 'ARTICLE_2879', 'ARTICLE_1788',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0064',
#   array(['ARTICLE_0664', 'ARTICLE_0587', 'ARTICLE_1975', 'ARTICLE_0575',
#          'ARTICLE_2364'], dtype=object)],
#  ['USER_0065',
#   array(['ARTICLE_2201', 'ARTICLE_2438', 'ARTICLE_2889', 'ARTICLE_2297',
#          'ARTICLE_1393'], dtype=object)],
#  ['USER_0066',
#   array(['ARTICLE_1940', 'ARTICLE_2422', 'ARTICLE_1449', 'ARTICLE_1891',
#          'ARTICLE_1281'], dtype=object)],
#  ['USER_0067',
#   array(['ARTICLE_2991', 'ARTICLE_0120', 'ARTICLE_1891', 'ARTICLE_1940',
#          'ARTICLE_1740'], dtype=object)],
#  ['USER_0068',
#   array(['ARTICLE_0968', 'ARTICLE_2879', 'ARTICLE_2493', 'ARTICLE_1092',
#          'ARTICLE_0958'], dtype=object)],
#  ['USER_0069',
#   array(['ARTICLE_0068', 'ARTICLE_0259', 'ARTICLE_2899', 'ARTICLE_1420',
#          'ARTICLE_1465'], dtype=object)],
#  ['USER_0070',
#   array(['ARTICLE_2129', 'ARTICLE_2409', 'ARTICLE_0782', 'ARTICLE_1983',
#          'ARTICLE_0351'], dtype=object)],
#  ['USER_0071',
#   array(['ARTICLE_1910', 'ARTICLE_1351', 'ARTICLE_2409', 'ARTICLE_2879',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0072',
#   array(['ARTICLE_1159', 'ARTICLE_0457', 'ARTICLE_2017', 'ARTICLE_1498',
#          'ARTICLE_0432'], dtype=object)],
#  ['USER_0073',
#   array(['ARTICLE_2782', 'ARTICLE_0419', 'ARTICLE_1132', 'ARTICLE_1568',
#          'ARTICLE_1694'], dtype=object)],
#  ['USER_0074',
#   array(['ARTICLE_1541', 'ARTICLE_1910', 'ARTICLE_0361', 'ARTICLE_2172',
#          'ARTICLE_0917'], dtype=object)],
#  ['USER_0075',
#   array(['ARTICLE_1185', 'ARTICLE_1233', 'ARTICLE_1332', 'ARTICLE_1732',
#          'ARTICLE_2294'], dtype=object)],
#  ['USER_0076',
#   array(['ARTICLE_2118', 'ARTICLE_2052', 'ARTICLE_2409', 'ARTICLE_2879',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0077',
#   array(['ARTICLE_0442', 'ARTICLE_1008', 'ARTICLE_0065', 'ARTICLE_1092',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0078',
#   array(['ARTICLE_2221', 'ARTICLE_0693', 'ARTICLE_1397', 'ARTICLE_2288',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0079',
#   array(['ARTICLE_1177', 'ARTICLE_1418', 'ARTICLE_0088', 'ARTICLE_0086',
#          'ARTICLE_0339'], dtype=object)],
#  ['USER_0080',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1788', 'ARTICLE_0445',
#          'ARTICLE_1252'], dtype=object)],
#  ['USER_0081',
#   array(['ARTICLE_0335', 'ARTICLE_1967', 'ARTICLE_0693', 'ARTICLE_1246',
#          'ARTICLE_0916'], dtype=object)],
#  ['USER_0082',
#   array(['ARTICLE_2879', 'ARTICLE_1982', 'ARTICLE_0941', 'ARTICLE_1788',
#          'ARTICLE_2782'], dtype=object)],
#  ['USER_0083',
#   array(['ARTICLE_0610', 'ARTICLE_1305', 'ARTICLE_0436', 'ARTICLE_2072',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0084',
#   array(['ARTICLE_0249', 'ARTICLE_1474', 'ARTICLE_1249', 'ARTICLE_0927',
#          'ARTICLE_2868'], dtype=object)],
#  ['USER_0085',
#   array(['ARTICLE_0445', 'ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_1351',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0086',
#   array(['ARTICLE_0912', 'ARTICLE_0640', 'ARTICLE_2596', 'ARTICLE_2337',
#          'ARTICLE_1350'], dtype=object)],
#  ['USER_0087',
#   array(['ARTICLE_1351', 'ARTICLE_1910', 'ARTICLE_2409', 'ARTICLE_2879',
#          'ARTICLE_0744'], dtype=object)],
#  ['USER_0088',
#   array(['ARTICLE_2241', 'ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1092',
#          'ARTICLE_0442'], dtype=object)],
#  ['USER_0089',
#   array(['ARTICLE_2573', 'ARTICLE_0364', 'ARTICLE_2424', 'ARTICLE_2562',
#          'ARTICLE_0882'], dtype=object)],
#  ['USER_0090',
#   array(['ARTICLE_2378', 'ARTICLE_2164', 'ARTICLE_2488', 'ARTICLE_0284',
#          'ARTICLE_0613'], dtype=object)],
#  ['USER_0091',
#   array(['ARTICLE_2357', 'ARTICLE_1192', 'ARTICLE_1714', 'ARTICLE_2026',
#          'ARTICLE_1906'], dtype=object)],
#  ['USER_0092',
#   array(['ARTICLE_1498', 'ARTICLE_2409', 'ARTICLE_1351', 'ARTICLE_2879',
#          'ARTICLE_1108'], dtype=object)],
#  ['USER_0093',
#   array(['ARTICLE_2126', 'ARTICLE_0445', 'ARTICLE_2052', 'ARTICLE_2473',
#          'ARTICLE_0226'], dtype=object)],
#  ['USER_0094',
#   array(['ARTICLE_2938', 'ARTICLE_2601', 'ARTICLE_1580', 'ARTICLE_1624',
#          'ARTICLE_1652'], dtype=object)],
#  ['USER_0095',
#   array(['ARTICLE_1788', 'ARTICLE_1018', 'ARTICLE_2879', 'ARTICLE_1982',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0096',
#   array(['ARTICLE_0419', 'ARTICLE_0046', 'ARTICLE_1356', 'ARTICLE_2736',
#          'ARTICLE_0333'], dtype=object)],
#  ['USER_0097',
#   array(['ARTICLE_1028', 'ARTICLE_0916', 'ARTICLE_1415', 'ARTICLE_2879',
#          'ARTICLE_1018'], dtype=object)],
#  ['USER_0098',
#   array(['ARTICLE_2096', 'ARTICLE_0610', 'ARTICLE_2837', 'ARTICLE_2409',
#          'ARTICLE_1608'], dtype=object)],
#  ['USER_0099',
#   array(['ARTICLE_2879', 'ARTICLE_2668', 'ARTICLE_0868', 'ARTICLE_2409',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0100',
#   array(['ARTICLE_2782', 'ARTICLE_0436', 'ARTICLE_1333', 'ARTICLE_0958',
#          'ARTICLE_2203'], dtype=object)],
#  ['USER_0101',
#   array(['ARTICLE_1949', 'ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1788',
#          'ARTICLE_2597'], dtype=object)],
#  ['USER_0102',
#   array(['ARTICLE_0852', 'ARTICLE_1803', 'ARTICLE_0079', 'ARTICLE_0354',
#          'ARTICLE_2209'], dtype=object)],
#  ['USER_0103',
#   array(['ARTICLE_1617', 'ARTICLE_2737', 'ARTICLE_2131', 'ARTICLE_0258',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0104',
#   array(['ARTICLE_2406', 'ARTICLE_1673', 'ARTICLE_1092', 'ARTICLE_0086',
#          'ARTICLE_0968'], dtype=object)],
#  ['USER_0105',
#   array(['ARTICLE_2409', 'ARTICLE_1351', 'ARTICLE_0803', 'ARTICLE_2879',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0106',
#   array(['ARTICLE_1092', 'ARTICLE_2879', 'ARTICLE_2782', 'ARTICLE_2409',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0107',
#   array(['ARTICLE_2630', 'ARTICLE_0968', 'ARTICLE_0086', 'ARTICLE_0339',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0108',
#   array(['ARTICLE_2879', 'ARTICLE_1752', 'ARTICLE_1018', 'ARTICLE_1252',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0109',
#   array(['ARTICLE_0931', 'ARTICLE_2268', 'ARTICLE_0780', 'ARTICLE_2879',
#          'ARTICLE_1351'], dtype=object)],
#  ['USER_0110',
#   array(['ARTICLE_0592', 'ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1092',
#          'ARTICLE_0968'], dtype=object)],
#  ['USER_0111',
#   array(['ARTICLE_2291', 'ARTICLE_1777', 'ARTICLE_0329', 'ARTICLE_0965',
#          'ARTICLE_1841'], dtype=object)],
#  ['USER_0112',
#   array(['ARTICLE_2422', 'ARTICLE_1449', 'ARTICLE_2873', 'ARTICLE_0532',
#          'ARTICLE_2496'], dtype=object)],
#  ['USER_0113',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1504', 'ARTICLE_1788',
#          'ARTICLE_0744'], dtype=object)],
#  ['USER_0114',
#   array(['ARTICLE_1351', 'ARTICLE_1498', 'ARTICLE_2535', 'ARTICLE_2409',
#          'ARTICLE_1788'], dtype=object)],
#  ['USER_0115',
#   array(['ARTICLE_0968', 'ARTICLE_2148', 'ARTICLE_1601', 'ARTICLE_1092',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0116',
#   array(['ARTICLE_2259', 'ARTICLE_0912', 'ARTICLE_3006', 'ARTICLE_0218',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0117',
#   array(['ARTICLE_2347', 'ARTICLE_2904', 'ARTICLE_2140', 'ARTICLE_2151',
#          'ARTICLE_1891'], dtype=object)],
#  ['USER_0118',
#   array(['ARTICLE_1351', 'ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1504',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0119',
#   array(['ARTICLE_1891', 'ARTICLE_1351', 'ARTICLE_1638', 'ARTICLE_1498',
#          'ARTICLE_0267'], dtype=object)],
#  ['USER_0120',
#   array(['ARTICLE_2782', 'ARTICLE_0436', 'ARTICLE_0744', 'ARTICLE_2879',
#          'ARTICLE_1999'], dtype=object)],
#  ['USER_0121',
#   array(['ARTICLE_1439', 'ARTICLE_1383', 'ARTICLE_0363', 'ARTICLE_0733',
#          'ARTICLE_0588'], dtype=object)],
#  ['USER_0122',
#   array(['ARTICLE_0436', 'ARTICLE_2764', 'ARTICLE_1333', 'ARTICLE_2203',
#          'ARTICLE_1485'], dtype=object)],
#  ['USER_0123',
#   array(['ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_1982', 'ARTICLE_0445',
#          'ARTICLE_1504'], dtype=object)],
#  ['USER_0124',
#   array(['ARTICLE_2085', 'ARTICLE_1036', 'ARTICLE_2195', 'ARTICLE_1648',
#          'ARTICLE_0479'], dtype=object)],
#  ['USER_0125',
#   array(['ARTICLE_1841', 'ARTICLE_1474', 'ARTICLE_2879', 'ARTICLE_1094',
#          'ARTICLE_1018'], dtype=object)],
#  ['USER_0126',
#   array(['ARTICLE_2879', 'ARTICLE_1504', 'ARTICLE_2409', 'ARTICLE_1018',
#          'ARTICLE_1252'], dtype=object)],
#  ['USER_0127',
#   array(['ARTICLE_0705', 'ARTICLE_1108', 'ARTICLE_1448', 'ARTICLE_2216',
#          'ARTICLE_1159'], dtype=object)],
#  ['USER_0128',
#   array(['ARTICLE_0635', 'ARTICLE_2889', 'ARTICLE_2755', 'ARTICLE_0971',
#          'ARTICLE_0829'], dtype=object)],
#  ['USER_0129',
#   array(['ARTICLE_2879', 'ARTICLE_1351', 'ARTICLE_2409', 'ARTICLE_1092',
#          'ARTICLE_0744'], dtype=object)],
#  ['USER_0130',
#   array(['ARTICLE_1351', 'ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_1982',
#          'ARTICLE_1788'], dtype=object)],
#  ['USER_0131',
#   array(['ARTICLE_0385', 'ARTICLE_1383', 'ARTICLE_1661', 'ARTICLE_1825',
#          'ARTICLE_1691'], dtype=object)],
#  ['USER_0132',
#   array(['ARTICLE_2694', 'ARTICLE_2656', 'ARTICLE_2879', 'ARTICLE_1092',
#          'ARTICLE_0744'], dtype=object)],
#  ['USER_0133',
#   array(['ARTICLE_2587', 'ARTICLE_2968', 'ARTICLE_1432', 'ARTICLE_2568',
#          'ARTICLE_1841'], dtype=object)],
#  ['USER_0134',
#   array(['ARTICLE_1910', 'ARTICLE_0361', 'ARTICLE_2879', 'ARTICLE_1361',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0135',
#   array(['ARTICLE_1292', 'ARTICLE_2879', 'ARTICLE_1351', 'ARTICLE_0442',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0136',
#   array(['ARTICLE_2782', 'ARTICLE_1824', 'ARTICLE_1351', 'ARTICLE_2879',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0137',
#   array(['ARTICLE_1018', 'ARTICLE_0237', 'ARTICLE_2879', 'ARTICLE_1982',
#          'ARTICLE_1252'], dtype=object)],
#  ['USER_0138',
#   array(['ARTICLE_1911', 'ARTICLE_0400', 'ARTICLE_1809', 'ARTICLE_1270',
#          'ARTICLE_2081'], dtype=object)],
#  ['USER_0139',
#   array(['ARTICLE_1273', 'ARTICLE_1795', 'ARTICLE_0161', 'ARTICLE_2166',
#          'ARTICLE_1287'], dtype=object)],
#  ['USER_0140',
#   array(['ARTICLE_1601', 'ARTICLE_0561', 'ARTICLE_0968', 'ARTICLE_0088',
#          'ARTICLE_0339'], dtype=object)],
#  ['USER_0141',
#   array(['ARTICLE_1946', 'ARTICLE_2868', 'ARTICLE_2188', 'ARTICLE_1891',
#          'ARTICLE_0687'], dtype=object)],
#  ['USER_0142',
#   array(['ARTICLE_2021', 'ARTICLE_1601', 'ARTICLE_0968', 'ARTICLE_0483',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0143',
#   array(['ARTICLE_2592', 'ARTICLE_1092', 'ARTICLE_2782', 'ARTICLE_2879',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0144',
#   array(['ARTICLE_0677', 'ARTICLE_0805', 'ARTICLE_0968', 'ARTICLE_2533',
#          'ARTICLE_1828'], dtype=object)],
#  ['USER_0145',
#   array(['ARTICLE_0744', 'ARTICLE_0868', 'ARTICLE_1092', 'ARTICLE_2879',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0146',
#   array(['ARTICLE_2140', 'ARTICLE_0085', 'ARTICLE_2324', 'ARTICLE_2347',
#          'ARTICLE_2224'], dtype=object)],
#  ['USER_0147',
#   array(['ARTICLE_1351', 'ARTICLE_0347', 'ARTICLE_2268', 'ARTICLE_1295',
#          'ARTICLE_0038'], dtype=object)],
#  ['USER_0148',
#   array(['ARTICLE_2782', 'ARTICLE_1999', 'ARTICLE_2879', 'ARTICLE_1982',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0149',
#   array(['ARTICLE_1270', 'ARTICLE_2721', 'ARTICLE_1380', 'ARTICLE_1739',
#          'ARTICLE_2178'], dtype=object)],
#  ['USER_0150',
#   array(['ARTICLE_2406', 'ARTICLE_1673', 'ARTICLE_1092', 'ARTICLE_0086',
#          'ARTICLE_0968'], dtype=object)],
#  ['USER_0151',
#   array(['ARTICLE_1601', 'ARTICLE_0610', 'ARTICLE_2832', 'ARTICLE_0968',
#          'ARTICLE_0088'], dtype=object)],
#  ['USER_0152',
#   array(['ARTICLE_2409', 'ARTICLE_1351', 'ARTICLE_1788', 'ARTICLE_2879',
#          'ARTICLE_0926'], dtype=object)],
#  ['USER_0153',
#   array(['ARTICLE_2409', 'ARTICLE_2656', 'ARTICLE_1351', 'ARTICLE_2197',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0154',
#   array(['ARTICLE_2183', 'ARTICLE_1503', 'ARTICLE_1841', 'ARTICLE_2409',
#          'ARTICLE_1018'], dtype=object)],
#  ['USER_0155',
#   array(['ARTICLE_0644', 'ARTICLE_1652', 'ARTICLE_2601', 'ARTICLE_0000',
#          'ARTICLE_1511'], dtype=object)],
#  ['USER_0156',
#   array(['ARTICLE_1841', 'ARTICLE_2879', 'ARTICLE_0965', 'ARTICLE_0592',
#          'ARTICLE_1252'], dtype=object)],
#  ['USER_0157',
#   array(['ARTICLE_0456', 'ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_1092',
#          'ARTICLE_0614'], dtype=object)],
#  ['USER_0158',
#   array(['ARTICLE_1351', 'ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_1076',
#          'ARTICLE_1788'], dtype=object)],
#  ['USER_0159',
#   array(['ARTICLE_1397', 'ARTICLE_2221', 'ARTICLE_2998', 'ARTICLE_0693',
#          'ARTICLE_1104'], dtype=object)],
#  ['USER_0160',
#   array(['ARTICLE_2879', 'ARTICLE_1910', 'ARTICLE_2096', 'ARTICLE_2409',
#          'ARTICLE_1788'], dtype=object)],
#  ['USER_0161',
#   array(['ARTICLE_2879', 'ARTICLE_1982', 'ARTICLE_2118', 'ARTICLE_2533',
#          'ARTICLE_1120'], dtype=object)],
#  ['USER_0163',
#   array(['ARTICLE_2782', 'ARTICLE_0744', 'ARTICLE_0203', 'ARTICLE_1092',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0164',
#   array(['ARTICLE_2992', 'ARTICLE_1788', 'ARTICLE_2898', 'ARTICLE_2668',
#          'ARTICLE_1018'], dtype=object)],
#  ['USER_0165',
#   array(['ARTICLE_2493', 'ARTICLE_1092', 'ARTICLE_2879', 'ARTICLE_2259',
#          'ARTICLE_0968'], dtype=object)],
#  ['USER_0166',
#   array(['ARTICLE_0843', 'ARTICLE_1744', 'ARTICLE_1644', 'ARTICLE_0313',
#          'ARTICLE_2310'], dtype=object)],
#  ['USER_0167',
#   array(['ARTICLE_1270', 'ARTICLE_1281', 'ARTICLE_2991', 'ARTICLE_1739',
#          'ARTICLE_2399'], dtype=object)],
#  ['USER_0168',
#   array(['ARTICLE_0958', 'ARTICLE_0203', 'ARTICLE_2879', 'ARTICLE_1092',
#          'ARTICLE_2782'], dtype=object)],
#  ['USER_0169',
#   array(['ARTICLE_1108', 'ARTICLE_1624', 'ARTICLE_0060', 'ARTICLE_1112',
#          'ARTICLE_1918'], dtype=object)],
#  ['USER_0170',
#   array(['ARTICLE_1999', 'ARTICLE_1910', 'ARTICLE_2879', 'ARTICLE_1018',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0171',
#   array(['ARTICLE_2699', 'ARTICLE_0106', 'ARTICLE_2806', 'ARTICLE_0668',
#          'ARTICLE_1053'], dtype=object)],
#  ['USER_0172',
#   array(['ARTICLE_1092', 'ARTICLE_0968', 'ARTICLE_0203', 'ARTICLE_1333',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0173',
#   array(['ARTICLE_1498', 'ARTICLE_1119', 'ARTICLE_2364', 'ARTICLE_0060',
#          'ARTICLE_0038'], dtype=object)],
#  ['USER_0174',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_1018',
#          'ARTICLE_1752'], dtype=object)],
#  ['USER_0175',
#   array(['ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_2409', 'ARTICLE_1910',
#          'ARTICLE_1018'], dtype=object)],
#  ['USER_0176',
#   array(['ARTICLE_0436', 'ARTICLE_1628', 'ARTICLE_2045', 'ARTICLE_1329',
#          'ARTICLE_2158'], dtype=object)],
#  ['USER_0177',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_0968',
#          'ARTICLE_1910'], dtype=object)],
#  ['USER_0178',
#   array(['ARTICLE_1351', 'ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_1788',
#          'ARTICLE_0803'], dtype=object)],
#  ['USER_0179',
#   array(['ARTICLE_1891', 'ARTICLE_1119', 'ARTICLE_1351', 'ARTICLE_0120',
#          'ARTICLE_1498'], dtype=object)],
#  ['USER_0180',
#   array(['ARTICLE_0289', 'ARTICLE_2740', 'ARTICLE_1641', 'ARTICLE_1474',
#          'ARTICLE_2345'], dtype=object)],
#  ['USER_0181',
#   array(['ARTICLE_2455', 'ARTICLE_1624', 'ARTICLE_1498', 'ARTICLE_0038',
#          'ARTICLE_2623'], dtype=object)],
#  ['USER_0182',
#   array(['ARTICLE_2129', 'ARTICLE_1983', 'ARTICLE_2409', 'ARTICLE_1092',
#          'ARTICLE_0782'], dtype=object)],
#  ['USER_0183',
#   array(['ARTICLE_1177', 'ARTICLE_1092', 'ARTICLE_2781', 'ARTICLE_2409',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0184',
#   array(['ARTICLE_0852', 'ARTICLE_0354', 'ARTICLE_2308', 'ARTICLE_0676',
#          'ARTICLE_0079'], dtype=object)],
#  ['USER_0185',
#   array(['ARTICLE_2221', 'ARTICLE_2323', 'ARTICLE_1608', 'ARTICLE_2914',
#          'ARTICLE_1351'], dtype=object)],
#  ['USER_0186',
#   array(['ARTICLE_0000', 'ARTICLE_1511', 'ARTICLE_0644', 'ARTICLE_0786',
#          'ARTICLE_2754'], dtype=object)],
#  ['USER_0187',
#   array(['ARTICLE_0864', 'ARTICLE_1947', 'ARTICLE_1492', 'ARTICLE_0263',
#          'ARTICLE_0497'], dtype=object)],
#  ['USER_0188',
#   array(['ARTICLE_0782', 'ARTICLE_2409', 'ARTICLE_2129', 'ARTICLE_1606',
#          'ARTICLE_2932'], dtype=object)],
#  ['USER_0189',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1351', 'ARTICLE_1092',
#          'ARTICLE_1788'], dtype=object)],
#  ['USER_0190',
#   array(['ARTICLE_2706', 'ARTICLE_0901', 'ARTICLE_1524', 'ARTICLE_1903',
#          'ARTICLE_0079'], dtype=object)],
#  ['USER_0191',
#   array(['ARTICLE_0755', 'ARTICLE_0763', 'ARTICLE_0279', 'ARTICLE_1046',
#          'ARTICLE_0760'], dtype=object)],
#  ['USER_0192',
#   array(['ARTICLE_0945', 'ARTICLE_2447', 'ARTICLE_2760', 'ARTICLE_1092',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0193',
#   array(['ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_2782', 'ARTICLE_2409',
#          'ARTICLE_0744'], dtype=object)],
#  ['USER_0194',
#   array(['ARTICLE_2787', 'ARTICLE_0039', 'ARTICLE_1085', 'ARTICLE_0457',
#          'ARTICLE_1803'], dtype=object)],
#  ['USER_0195',
#   array(['ARTICLE_2409', 'ARTICLE_1005', 'ARTICLE_2879', 'ARTICLE_1474',
#          'ARTICLE_1351'], dtype=object)],
#  ['USER_0196',
#   array(['ARTICLE_0445', 'ARTICLE_2656', 'ARTICLE_1351', 'ARTICLE_2879',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0197',
#   array(['ARTICLE_0270', 'ARTICLE_2889', 'ARTICLE_1982', 'ARTICLE_2424',
#          'ARTICLE_1788'], dtype=object)],
#  ['USER_0198',
#   array(['ARTICLE_0958', 'ARTICLE_2115', 'ARTICLE_2879', 'ARTICLE_1305',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0199',
#   array(['ARTICLE_2703', 'ARTICLE_0526', 'ARTICLE_2870', 'ARTICLE_0175',
#          'ARTICLE_1848'], dtype=object)],
#  ['USER_0200',
#   array(['ARTICLE_0867', 'ARTICLE_2704', 'ARTICLE_0803', 'ARTICLE_1018',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0201',
#   array(['ARTICLE_0968', 'ARTICLE_0931', 'ARTICLE_2021', 'ARTICLE_2879',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0202',
#   array(['ARTICLE_1072', 'ARTICLE_2195', 'ARTICLE_2085', 'ARTICLE_1639',
#          'ARTICLE_0479'], dtype=object)],
#  ['USER_0203',
#   array(['ARTICLE_2096', 'ARTICLE_1183', 'ARTICLE_0200', 'ARTICLE_1788',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0204',
#   array(['ARTICLE_0979', 'ARTICLE_0045', 'ARTICLE_1905', 'ARTICLE_0347',
#          'ARTICLE_2931'], dtype=object)],
#  ['USER_0205',
#   array(['ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_2409', 'ARTICLE_0445',
#          'ARTICLE_0203'], dtype=object)],
#  ['USER_0206',
#   array(['ARTICLE_2782', 'ARTICLE_0968', 'ARTICLE_2879', 'ARTICLE_0445',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0207',
#   array(['ARTICLE_0806', 'ARTICLE_1605', 'ARTICLE_1990', 'ARTICLE_2712',
#          'ARTICLE_0338'], dtype=object)],
#  ['USER_0208',
#   array(['ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_2409', 'ARTICLE_1910',
#          'ARTICLE_0803'], dtype=object)],
#  ['USER_0209',
#   array(['ARTICLE_2061', 'ARTICLE_1032', 'ARTICLE_1916', 'ARTICLE_2140',
#          'ARTICLE_2434'], dtype=object)],
#  ['USER_0210',
#   array(['ARTICLE_0445', 'ARTICLE_2879', 'ARTICLE_2473', 'ARTICLE_1910',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0211',
#   array(['ARTICLE_2651', 'ARTICLE_2684', 'ARTICLE_0367', 'ARTICLE_2258',
#          'ARTICLE_0712'], dtype=object)],
#  ['USER_0212',
#   array(['ARTICLE_1380', 'ARTICLE_2267', 'ARTICLE_0540', 'ARTICLE_0941',
#          'ARTICLE_1739'], dtype=object)],
#  ['USER_0213',
#   array(['ARTICLE_1601', 'ARTICLE_1028', 'ARTICLE_1965', 'ARTICLE_2668',
#          'ARTICLE_0968'], dtype=object)],
#  ['USER_0214',
#   array(['ARTICLE_2441', 'ARTICLE_2806', 'ARTICLE_2991', 'ARTICLE_2721',
#          'ARTICLE_0668'], dtype=object)],
#  ['USER_0215',
#   array(['ARTICLE_1351', 'ARTICLE_0445', 'ARTICLE_1891', 'ARTICLE_2473',
#          'ARTICLE_1043'], dtype=object)],
#  ['USER_0216',
#   array(['ARTICLE_2782', 'ARTICLE_0436', 'ARTICLE_1333', 'ARTICLE_1292',
#          'ARTICLE_0958'], dtype=object)],
#  ['USER_0217',
#   array(['ARTICLE_1135', 'ARTICLE_1489', 'ARTICLE_0690', 'ARTICLE_2014',
#          'ARTICLE_2339'], dtype=object)],
#  ['USER_0218',
#   array(['ARTICLE_0218', 'ARTICLE_2063', 'ARTICLE_0442', 'ARTICLE_2705',
#          'ARTICLE_1697'], dtype=object)],
#  ['USER_0219',
#   array(['ARTICLE_2552', 'ARTICLE_0974', 'ARTICLE_0844', 'ARTICLE_0372',
#          'ARTICLE_1841'], dtype=object)],
#  ['USER_0220',
#   array(['ARTICLE_2409', 'ARTICLE_1351', 'ARTICLE_2879', 'ARTICLE_1092',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0221',
#   array(['ARTICLE_2850', 'ARTICLE_2983', 'ARTICLE_1372', 'ARTICLE_1449',
#          'ARTICLE_1940'], dtype=object)],
#  ['USER_0222',
#   array(['ARTICLE_2422', 'ARTICLE_1940', 'ARTICLE_1891', 'ARTICLE_1449',
#          'ARTICLE_2276'], dtype=object)],
#  ['USER_0223',
#   array(['ARTICLE_1862', 'ARTICLE_2209', 'ARTICLE_0079', 'ARTICLE_0354',
#          'ARTICLE_0457'], dtype=object)],
#  ['USER_0224',
#   array(['ARTICLE_2698', 'ARTICLE_0867', 'ARTICLE_2309', 'ARTICLE_0843',
#          'ARTICLE_1351'], dtype=object)],
#  ['USER_0225',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_0968',
#          'ARTICLE_2782'], dtype=object)],
#  ['USER_0226',
#   array(['ARTICLE_1788', 'ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_1982',
#          'ARTICLE_2424'], dtype=object)],
#  ['USER_0227',
#   array(['ARTICLE_1141', 'ARTICLE_2495', 'ARTICLE_2062', 'ARTICLE_0373',
#          'ARTICLE_1821'], dtype=object)],
#  ['USER_0228',
#   array(['ARTICLE_2879', 'ARTICLE_1982', 'ARTICLE_1092', 'ARTICLE_1018',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0229',
#   array(['ARTICLE_2561', 'ARTICLE_1187', 'ARTICLE_0711', 'ARTICLE_1698',
#          'ARTICLE_1482'], dtype=object)],
#  ['USER_0230',
#   array(['ARTICLE_2729', 'ARTICLE_2737', 'ARTICLE_2489', 'ARTICLE_0957',
#          'ARTICLE_0784'], dtype=object)],
#  ['USER_0231',
#   array(['ARTICLE_2868', 'ARTICLE_1740', 'ARTICLE_1772', 'ARTICLE_1883',
#          'ARTICLE_2991'], dtype=object)],
#  ['USER_0232',
#   array(['ARTICLE_0968', 'ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_2148',
#          'ARTICLE_1601'], dtype=object)],
#  ['USER_0233',
#   array(['ARTICLE_0265', 'ARTICLE_1743', 'ARTICLE_1885', 'ARTICLE_2323',
#          'ARTICLE_1666'], dtype=object)],
#  ['USER_0234',
#   array(['ARTICLE_1351', 'ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_0445',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0235',
#   array(['ARTICLE_2819', 'ARTICLE_0347', 'ARTICLE_1477', 'ARTICLE_2931',
#          'ARTICLE_2439'], dtype=object)],
#  ['USER_0236',
#   array(['ARTICLE_0380', 'ARTICLE_0212', 'ARTICLE_2404', 'ARTICLE_2682',
#          'ARTICLE_0940'], dtype=object)],
#  ['USER_0237',
#   array(['ARTICLE_2268', 'ARTICLE_1351', 'ARTICLE_2409', 'ARTICLE_0968',
#          'ARTICLE_0712'], dtype=object)],
#  ['USER_0238',
#   array(['ARTICLE_1076', 'ARTICLE_2493', 'ARTICLE_1287', 'ARTICLE_2879',
#          'ARTICLE_0968'], dtype=object)],
#  ['USER_0239',
#   array(['ARTICLE_2879', 'ARTICLE_0427', 'ARTICLE_1092', 'ARTICLE_0968',
#          'ARTICLE_0958'], dtype=object)],
#  ['USER_0240',
#   array(['ARTICLE_2311', 'ARTICLE_2722', 'ARTICLE_1982', 'ARTICLE_1252',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0241',
#   array(['ARTICLE_1177', 'ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_1945',
#          'ARTICLE_0780'], dtype=object)],
#  ['USER_0242',
#   array(['ARTICLE_1108', 'ARTICLE_1159', 'ARTICLE_0520', 'ARTICLE_2364',
#          'ARTICLE_1498'], dtype=object)],
#  ['USER_0243',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_2166', 'ARTICLE_0712',
#          'ARTICLE_1788'], dtype=object)],
#  ['USER_0244',
#   array(['ARTICLE_0931', 'ARTICLE_1240', 'ARTICLE_2879', 'ARTICLE_2409',
#          'ARTICLE_1788'], dtype=object)],
#  ['USER_0245',
#   array(['ARTICLE_0610', 'ARTICLE_2118', 'ARTICLE_2738', 'ARTICLE_0086',
#          'ARTICLE_0968'], dtype=object)],
#  ['USER_0246',
#   array(['ARTICLE_0958', 'ARTICLE_2879', 'ARTICLE_2668', 'ARTICLE_2782',
#          'ARTICLE_2115'], dtype=object)],
#  ['USER_0247',
#   array(['ARTICLE_1910', 'ARTICLE_0502', 'ARTICLE_2879', 'ARTICLE_2504',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0248',
#   array(['ARTICLE_1188', 'ARTICLE_1684', 'ARTICLE_1940', 'ARTICLE_0812',
#          'ARTICLE_2858'], dtype=object)],
#  ['USER_0249',
#   array(['ARTICLE_1824', 'ARTICLE_2570', 'ARTICLE_2911', 'ARTICLE_0436',
#          'ARTICLE_1652'], dtype=object)],
#  ['USER_0250',
#   array(['ARTICLE_2677', 'ARTICLE_1744', 'ARTICLE_0776', 'ARTICLE_0214',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0251',
#   array(['ARTICLE_0990', 'ARTICLE_2091', 'ARTICLE_1190', 'ARTICLE_0601',
#          'ARTICLE_2577'], dtype=object)],
#  ['USER_0252',
#   array(['ARTICLE_1891', 'ARTICLE_1940', 'ARTICLE_1498', 'ARTICLE_0120',
#          'ARTICLE_1955'], dtype=object)],
#  ['USER_0253',
#   array(['ARTICLE_0108', 'ARTICLE_2474', 'ARTICLE_0255', 'ARTICLE_0887',
#          'ARTICLE_1324'], dtype=object)],
#  ['USER_0254',
#   array(['ARTICLE_1821', 'ARTICLE_0373', 'ARTICLE_1603', 'ARTICLE_1624',
#          'ARTICLE_2012'], dtype=object)],
#  ['USER_0255',
#   array(['ARTICLE_2790', 'ARTICLE_0081', 'ARTICLE_2980', 'ARTICLE_0961',
#          'ARTICLE_1747'], dtype=object)],
#  ['USER_0256',
#   array(['ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_2409', 'ARTICLE_0744',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0257',
#   array(['ARTICLE_2592', 'ARTICLE_2879', 'ARTICLE_1018', 'ARTICLE_2221',
#          'ARTICLE_1351'], dtype=object)],
#  ['USER_0258',
#   array(['ARTICLE_0925', 'ARTICLE_0176', 'ARTICLE_0003', 'ARTICLE_1649',
#          'ARTICLE_0162'], dtype=object)],
#  ['USER_0259',
#   array(['ARTICLE_2372', 'ARTICLE_0365', 'ARTICLE_0610', 'ARTICLE_2738',
#          'ARTICLE_1884'], dtype=object)],
#  ['USER_0260',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_1910',
#          'ARTICLE_0968'], dtype=object)],
#  ['USER_0261',
#   array(['ARTICLE_1018', 'ARTICLE_2409', 'ARTICLE_1252', 'ARTICLE_1788',
#          'ARTICLE_1761'], dtype=object)],
#  ['USER_0262',
#   array(['ARTICLE_1192', 'ARTICLE_1470', 'ARTICLE_1624', 'ARTICLE_0737',
#          'ARTICLE_2017'], dtype=object)],
#  ['USER_0263',
#   array(['ARTICLE_2274', 'ARTICLE_1447', 'ARTICLE_1092', 'ARTICLE_2879',
#          'ARTICLE_1252'], dtype=object)],
#  ['USER_0264',
#   array(['ARTICLE_1351', 'ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_2409',
#          'ARTICLE_0803'], dtype=object)],
#  ['USER_0265',
#   array(['ARTICLE_1669', 'ARTICLE_2045', 'ARTICLE_2868', 'ARTICLE_1788',
#          'ARTICLE_0712'], dtype=object)],
#  ['USER_0266',
#   array(['ARTICLE_0780', 'ARTICLE_2165', 'ARTICLE_1887', 'ARTICLE_2900',
#          'ARTICLE_2632'], dtype=object)],
#  ['USER_0267',
#   array(['ARTICLE_2409', 'ARTICLE_2568', 'ARTICLE_1183', 'ARTICLE_1788',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0268',
#   array(['ARTICLE_0784', 'ARTICLE_1881', 'ARTICLE_1213', 'ARTICLE_1669',
#          'ARTICLE_1788'], dtype=object)],
#  ['USER_0269',
#   array(['ARTICLE_2274', 'ARTICLE_2237', 'ARTICLE_2879', 'ARTICLE_1252',
#          'ARTICLE_1176'], dtype=object)],
#  ['USER_0270',
#   array(['ARTICLE_1351', 'ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_2879',
#          'ARTICLE_1608'], dtype=object)],
#  ['USER_0271',
#   array(['ARTICLE_3006', 'ARTICLE_1577', 'ARTICLE_1882', 'ARTICLE_2268',
#          'ARTICLE_1440'], dtype=object)],
#  ['USER_0272',
#   array(['ARTICLE_2409', 'ARTICLE_1351', 'ARTICLE_2879', 'ARTICLE_1092',
#          'ARTICLE_0445'], dtype=object)],
#  ['USER_0273',
#   array(['ARTICLE_1522', 'ARTICLE_2736', 'ARTICLE_0644', 'ARTICLE_0784',
#          'ARTICLE_1798'], dtype=object)],
#  ['USER_0274',
#   array(['ARTICLE_0213', 'ARTICLE_1091', 'ARTICLE_0561', 'ARTICLE_1673',
#          'ARTICLE_1172'], dtype=object)],
#  ['USER_0275',
#   array(['ARTICLE_2587', 'ARTICLE_0102', 'ARTICLE_2023', 'ARTICLE_2912',
#          'ARTICLE_1943'], dtype=object)],
#  ['USER_0276',
#   array(['ARTICLE_2096', 'ARTICLE_1910', 'ARTICLE_2409', 'ARTICLE_1177',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0277',
#   array(['ARTICLE_2523', 'ARTICLE_2337', 'ARTICLE_1682', 'ARTICLE_2596',
#          'ARTICLE_2991'], dtype=object)],
#  ['USER_0278',
#   array(['ARTICLE_0436', 'ARTICLE_1427', 'ARTICLE_2127', 'ARTICLE_2514',
#          'ARTICLE_1333'], dtype=object)],
#  ['USER_0279',
#   array(['ARTICLE_1544', 'ARTICLE_0445', 'ARTICLE_1092', 'ARTICLE_2409',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0280',
#   array(['ARTICLE_1351', 'ARTICLE_1673', 'ARTICLE_2409', 'ARTICLE_1012',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0281',
#   array(['ARTICLE_0931', 'ARTICLE_0780', 'ARTICLE_0712', 'ARTICLE_2879',
#          'ARTICLE_0265'], dtype=object)],
#  ['USER_0282',
#   array(['ARTICLE_0086', 'ARTICLE_1601', 'ARTICLE_0968', 'ARTICLE_2879',
#          'ARTICLE_0339'], dtype=object)],
#  ['USER_0283',
#   array(['ARTICLE_0520', 'ARTICLE_2254', 'ARTICLE_0107', 'ARTICLE_1617',
#          'ARTICLE_1685'], dtype=object)],
#  ['USER_0284',
#   array(['ARTICLE_1674', 'ARTICLE_2385', 'ARTICLE_2209', 'ARTICLE_0886',
#          'ARTICLE_0079'], dtype=object)],
#  ['USER_0285',
#   array(['ARTICLE_1547', 'ARTICLE_1080', 'ARTICLE_1815', 'ARTICLE_0864',
#          'ARTICLE_1917'], dtype=object)],
#  ['USER_0286',
#   array(['ARTICLE_1524', 'ARTICLE_1953', 'ARTICLE_2406', 'ARTICLE_2967',
#          'ARTICLE_0033'], dtype=object)],
#  ['USER_0287',
#   array(['ARTICLE_1306', 'ARTICLE_2045', 'ARTICLE_0886', 'ARTICLE_2127',
#          'ARTICLE_2216'], dtype=object)],
#  ['USER_0288',
#   array(['ARTICLE_2668', 'ARTICLE_2722', 'ARTICLE_2879', 'ARTICLE_2118',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0289',
#   array(['ARTICLE_2062', 'ARTICLE_0311', 'ARTICLE_2442', 'ARTICLE_1672',
#          'ARTICLE_0877'], dtype=object)],
#  ['USER_0290',
#   array(['ARTICLE_0457', 'ARTICLE_2579', 'ARTICLE_2485', 'ARTICLE_0905',
#          'ARTICLE_0079'], dtype=object)],
#  ['USER_0291',
#   array(['ARTICLE_1952', 'ARTICLE_0926', 'ARTICLE_1498', 'ARTICLE_1119',
#          'ARTICLE_2535'], dtype=object)],
#  ['USER_0292',
#   array(['ARTICLE_1952', 'ARTICLE_2816', 'ARTICLE_0108', 'ARTICLE_1891',
#          'ARTICLE_1690'], dtype=object)],
#  ['USER_0293',
#   array(['ARTICLE_0852', 'ARTICLE_1159', 'ARTICLE_2907', 'ARTICLE_0354',
#          'ARTICLE_1664'], dtype=object)],
#  ['USER_0294',
#   array(['ARTICLE_0509', 'ARTICLE_0978', 'ARTICLE_0213', 'ARTICLE_1172',
#          'ARTICLE_0506'], dtype=object)],
#  ['USER_0295',
#   array(['ARTICLE_1947', 'ARTICLE_1384', 'ARTICLE_2139', 'ARTICLE_1474',
#          'ARTICLE_1401'], dtype=object)],
#  ['USER_0296',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_1351',
#          'ARTICLE_1910'], dtype=object)],
#  ['USER_0297',
#   array(['ARTICLE_0784', 'ARTICLE_1392', 'ARTICLE_2166', 'ARTICLE_2462',
#          'ARTICLE_1795'], dtype=object)],
#  ['USER_0298',
#   array(['ARTICLE_0350', 'ARTICLE_1308', 'ARTICLE_2364', 'ARTICLE_1029',
#          'ARTICLE_0284'], dtype=object)],
#  ['USER_0299',
#   array(['ARTICLE_2782', 'ARTICLE_0553', 'ARTICLE_2879', 'ARTICLE_1982',
#          'ARTICLE_1018'], dtype=object)],
#  ['USER_0300',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1351', 'ARTICLE_1788',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0301',
#   array(['ARTICLE_2409', 'ARTICLE_1983', 'ARTICLE_2129', 'ARTICLE_2879',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0302',
#   array(['ARTICLE_0134', 'ARTICLE_2725', 'ARTICLE_1018', 'ARTICLE_2782',
#          'ARTICLE_0744'], dtype=object)],
#  ['USER_0303',
#   array(['ARTICLE_1416', 'ARTICLE_2889', 'ARTICLE_0254', 'ARTICLE_1281',
#          'ARTICLE_0445'], dtype=object)],
#  ['USER_0304',
#   array(['ARTICLE_2399', 'ARTICLE_0592', 'ARTICLE_1788', 'ARTICLE_1761',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0305',
#   array(['ARTICLE_2493', 'ARTICLE_1291', 'ARTICLE_1337', 'ARTICLE_2879',
#          'ARTICLE_2533'], dtype=object)],
#  ['USER_0306',
#   array(['ARTICLE_0502', 'ARTICLE_0173', 'ARTICLE_0561', 'ARTICLE_1910',
#          'ARTICLE_2183'], dtype=object)],
#  ['USER_0307',
#   array(['ARTICLE_0038', 'ARTICLE_1498', 'ARTICLE_1351', 'ARTICLE_2268',
#          'ARTICLE_0445'], dtype=object)],
#  ['USER_0308',
#   array(['ARTICLE_2879', 'ARTICLE_1910', 'ARTICLE_2409', 'ARTICLE_1092',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0309',
#   array(['ARTICLE_2099', 'ARTICLE_1749', 'ARTICLE_1739', 'ARTICLE_1089',
#          'ARTICLE_1270'], dtype=object)],
#  ['USER_0310',
#   array(['ARTICLE_0140', 'ARTICLE_0102', 'ARTICLE_2879', 'ARTICLE_2287',
#          'ARTICLE_0508'], dtype=object)],
#  ['USER_0311',
#   array(['ARTICLE_2879', 'ARTICLE_2782', 'ARTICLE_1092', 'ARTICLE_2576',
#          'ARTICLE_1504'], dtype=object)],
#  ['USER_0312',
#   array(['ARTICLE_2889', 'ARTICLE_2259', 'ARTICLE_2879', 'ARTICLE_1252',
#          'ARTICLE_1504'], dtype=object)],
#  ['USER_0313',
#   array(['ARTICLE_1841', 'ARTICLE_2930', 'ARTICLE_1544', 'ARTICLE_2879',
#          'ARTICLE_2279'], dtype=object)],
#  ['USER_0314',
#   array(['ARTICLE_0173', 'ARTICLE_1910', 'ARTICLE_0285', 'ARTICLE_0715',
#          'ARTICLE_2868'], dtype=object)],
#  ['USER_0315',
#   array(['ARTICLE_1252', 'ARTICLE_1982', 'ARTICLE_2668', 'ARTICLE_2879',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0316',
#   array(['ARTICLE_1092', 'ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1787',
#          'ARTICLE_0968'], dtype=object)],
#  ['USER_0317',
#   array(['ARTICLE_0061', 'ARTICLE_0446', 'ARTICLE_0569', 'ARTICLE_1693',
#          'ARTICLE_2570'], dtype=object)],
#  ['USER_0318',
#   array(['ARTICLE_2458', 'ARTICLE_1276', 'ARTICLE_2455', 'ARTICLE_1012',
#          'ARTICLE_1672'], dtype=object)],
#  ['USER_0319',
#   array(['ARTICLE_2706', 'ARTICLE_0169', 'ARTICLE_0079', 'ARTICLE_1152',
#          'ARTICLE_1862'], dtype=object)],
#  ['USER_0320',
#   array(['ARTICLE_2782', 'ARTICLE_0502', 'ARTICLE_2967', 'ARTICLE_1910',
#          'ARTICLE_2050'], dtype=object)],
#  ['USER_0321',
#   array(['ARTICLE_2129', 'ARTICLE_2409', 'ARTICLE_0782', 'ARTICLE_1983',
#          'ARTICLE_1788'], dtype=object)],
#  ['USER_0322',
#   array(['ARTICLE_2406', 'ARTICLE_2197', 'ARTICLE_0336', 'ARTICLE_2182',
#          'ARTICLE_1881'], dtype=object)],
#  ['USER_0323',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1351', 'ARTICLE_1018',
#          'ARTICLE_1788'], dtype=object)],
#  ['USER_0324',
#   array(['ARTICLE_2592', 'ARTICLE_1384', 'ARTICLE_2227', 'ARTICLE_1018',
#          'ARTICLE_2203'], dtype=object)],
#  ['USER_0325',
#   array(['ARTICLE_2698', 'ARTICLE_0784', 'ARTICLE_0339', 'ARTICLE_0088',
#          'ARTICLE_0086'], dtype=object)],
#  ['USER_0326',
#   array(['ARTICLE_1449', 'ARTICLE_1498', 'ARTICLE_1940', 'ARTICLE_2991',
#          'ARTICLE_1270'], dtype=object)],
#  ['USER_0327',
#   array(['ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_2409', 'ARTICLE_2782',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0328',
#   array(['ARTICLE_2120', 'ARTICLE_1274', 'ARTICLE_1936', 'ARTICLE_2215',
#          'ARTICLE_1417'], dtype=object)],
#  ['USER_0329',
#   array(['ARTICLE_0046', 'ARTICLE_2217', 'ARTICLE_0772', 'ARTICLE_0777',
#          'ARTICLE_0333'], dtype=object)],
#  ['USER_0330',
#   array(['ARTICLE_2024', 'ARTICLE_1648', 'ARTICLE_0479', 'ARTICLE_2085',
#          'ARTICLE_2195'], dtype=object)],
#  ['USER_0331',
#   array(['ARTICLE_1673', 'ARTICLE_2532', 'ARTICLE_0903', 'ARTICLE_1440',
#          'ARTICLE_1367'], dtype=object)],
#  ['USER_0332',
#   array(['ARTICLE_0226', 'ARTICLE_2879', 'ARTICLE_1910', 'ARTICLE_0102',
#          'ARTICLE_0803'], dtype=object)],
#  ['USER_0333',
#   array(['ARTICLE_2021', 'ARTICLE_3006', 'ARTICLE_1228', 'ARTICLE_1629',
#          'ARTICLE_0153'], dtype=object)],
#  ['USER_0334',
#   array(['ARTICLE_2894', 'ARTICLE_2668', 'ARTICLE_2782', 'ARTICLE_1206',
#          'ARTICLE_0427'], dtype=object)],
#  ['USER_0335',
#   array(['ARTICLE_2131', 'ARTICLE_0038', 'ARTICLE_1106', 'ARTICLE_0347',
#          'ARTICLE_0979'], dtype=object)],
#  ['USER_0336',
#   array(['ARTICLE_0457', 'ARTICLE_0079', 'ARTICLE_0731', 'ARTICLE_2512',
#          'ARTICLE_2485'], dtype=object)],
#  ['USER_0337',
#   array(['ARTICLE_2668', 'ARTICLE_2894', 'ARTICLE_1018', 'ARTICLE_1982',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0338',
#   array(['ARTICLE_1440', 'ARTICLE_1152', 'ARTICLE_0760', 'ARTICLE_1159',
#          'ARTICLE_2485'], dtype=object)],
#  ['USER_0339',
#   array(['ARTICLE_0968', 'ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_1910',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0340',
#   array(['ARTICLE_1859', 'ARTICLE_2237', 'ARTICLE_1982', 'ARTICLE_1504',
#          'ARTICLE_1880'], dtype=object)],
#  ['USER_0341',
#   array(['ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_0958', 'ARTICLE_2409',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0342',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_0445', 'ARTICLE_1788',
#          'ARTICLE_1351'], dtype=object)],
#  ['USER_0343',
#   array(['ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_0958', 'ARTICLE_2668',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0344',
#   array(['ARTICLE_0803', 'ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_1788',
#          'ARTICLE_1910'], dtype=object)],
#  ['USER_0345',
#   array(['ARTICLE_2311', 'ARTICLE_2274', 'ARTICLE_2879', 'ARTICLE_1092',
#          'ARTICLE_1252'], dtype=object)],
#  ['USER_0346',
#   array(['ARTICLE_0959', 'ARTICLE_0188', 'ARTICLE_2885', 'ARTICLE_2879',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0347',
#   array(['ARTICLE_2045', 'ARTICLE_1302', 'ARTICLE_0712', 'ARTICLE_2258',
#          'ARTICLE_2269'], dtype=object)],
#  ['USER_0348',
#   array(['ARTICLE_1351', 'ARTICLE_1891', 'ARTICLE_2268', 'ARTICLE_2347',
#          'ARTICLE_2422'], dtype=object)],
#  ['USER_0349',
#   array(['ARTICLE_0931', 'ARTICLE_2879', 'ARTICLE_0439', 'ARTICLE_2305',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0350',
#   array(['ARTICLE_1159', 'ARTICLE_1108', 'ARTICLE_0060', 'ARTICLE_2309',
#          'ARTICLE_0038'], dtype=object)],
#  ['USER_0351',
#   array(['ARTICLE_2112', 'ARTICLE_1647', 'ARTICLE_1579', 'ARTICLE_0071',
#          'ARTICLE_2328'], dtype=object)],
#  ['USER_0352',
#   array(['ARTICLE_0670', 'ARTICLE_1863', 'ARTICLE_0248', 'ARTICLE_1841',
#          'ARTICLE_0965'], dtype=object)],
#  ['USER_0353',
#   array(['ARTICLE_1714', 'ARTICLE_0944', 'ARTICLE_2600', 'ARTICLE_2224',
#          'ARTICLE_2776'], dtype=object)],
#  ['USER_0354',
#   array(['ARTICLE_1351', 'ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1092',
#          'ARTICLE_0968'], dtype=object)],
#  ['USER_0355',
#   array(['ARTICLE_2425', 'ARTICLE_0803', 'ARTICLE_2682', 'ARTICLE_1788',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0356',
#   array(['ARTICLE_0038', 'ARTICLE_1108', 'ARTICLE_1498', 'ARTICLE_2991',
#          'ARTICLE_0569'], dtype=object)],
#  ['USER_0357',
#   array(['ARTICLE_0610', 'ARTICLE_0968', 'ARTICLE_1601', 'ARTICLE_0086',
#          'ARTICLE_0088'], dtype=object)],
#  ['USER_0358',
#   array(['ARTICLE_1159', 'ARTICLE_2894', 'ARTICLE_1108', 'ARTICLE_1305',
#          'ARTICLE_0203'], dtype=object)],
#  ['USER_0359',
#   array(['ARTICLE_2879', 'ARTICLE_2044', 'ARTICLE_0968', 'ARTICLE_2533',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0360',
#   array(['ARTICLE_1384', 'ARTICLE_2131', 'ARTICLE_1950', 'ARTICLE_0865',
#          'ARTICLE_0276'], dtype=object)],
#  ['USER_0361',
#   array(['ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_1252', 'ARTICLE_1982',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0362',
#   array(['ARTICLE_1286', 'ARTICLE_0004', 'ARTICLE_0079', 'ARTICLE_2718',
#          'ARTICLE_0457'], dtype=object)],
#  ['USER_0363',
#   array(['ARTICLE_2668', 'ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_1982',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0364',
#   array(['ARTICLE_2782', 'ARTICLE_2012', 'ARTICLE_1999', 'ARTICLE_2879',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0365',
#   array(['ARTICLE_2529', 'ARTICLE_1524', 'ARTICLE_1777', 'ARTICLE_0965',
#          'ARTICLE_0404'], dtype=object)],
#  ['USER_0366',
#   array(['ARTICLE_2879', 'ARTICLE_0553', 'ARTICLE_1018', 'ARTICLE_1982',
#          'ARTICLE_0445'], dtype=object)],
#  ['USER_0367',
#   array(['ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_0958', 'ARTICLE_1982',
#          'ARTICLE_2668'], dtype=object)],
#  ['USER_0368',
#   array(['ARTICLE_1351', 'ARTICLE_1092', 'ARTICLE_2668', 'ARTICLE_2409',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0369',
#   array(['ARTICLE_0411', 'ARTICLE_2081', 'ARTICLE_1749', 'ARTICLE_0184',
#          'ARTICLE_0459'], dtype=object)],
#  ['USER_0370',
# ...
#  ['USER_0882',
#   array(['ARTICLE_1351', 'ARTICLE_1910', 'ARTICLE_0553', 'ARTICLE_2879',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0883',
#   array(['ARTICLE_1012', 'ARTICLE_2424', 'ARTICLE_1018', 'ARTICLE_2409',
#          'ARTICLE_0816'], dtype=object)],
#  ['USER_0884',
#   array(['ARTICLE_2311', 'ARTICLE_2782', 'ARTICLE_2409', 'ARTICLE_2879',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0885',
#   array(['ARTICLE_2409', 'ARTICLE_2668', 'ARTICLE_2879', 'ARTICLE_1982',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0886',
#   array(['ARTICLE_1601', 'ARTICLE_0968', 'ARTICLE_0086', 'ARTICLE_0339',
#          'ARTICLE_0088'], dtype=object)],
#  ['USER_0887',
#   array(['ARTICLE_0594', 'ARTICLE_2868', 'ARTICLE_0874', 'ARTICLE_0407',
#          'ARTICLE_0928'], dtype=object)],
#  ['USER_0888',
#   array(['ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_1292', 'ARTICLE_2879',
#          'ARTICLE_1910'], dtype=object)],
#  ['USER_0889',
#   array(['ARTICLE_1994', 'ARTICLE_2735', 'ARTICLE_0642', 'ARTICLE_0592',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0890',
#   array(['ARTICLE_0868', 'ARTICLE_2879', 'ARTICLE_2782', 'ARTICLE_1092',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0891',
#   array(['ARTICLE_1498', 'ARTICLE_1159', 'ARTICLE_1108', 'ARTICLE_0038',
#          'ARTICLE_0671'], dtype=object)],
#  ['USER_0892',
#   array(['ARTICLE_1608', 'ARTICLE_1910', 'ARTICLE_2409', 'ARTICLE_2879',
#          'ARTICLE_2782'], dtype=object)],
#  ['USER_0893',
#   array(['ARTICLE_1351', 'ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_1788',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0894',
#   array(['ARTICLE_2573', 'ARTICLE_2337', 'ARTICLE_1881', 'ARTICLE_1246',
#          'ARTICLE_2562'], dtype=object)],
#  ['USER_0895',
#   array(['ARTICLE_0974', 'ARTICLE_1252', 'ARTICLE_0838', 'ARTICLE_2409',
#          'ARTICLE_1018'], dtype=object)],
#  ['USER_0896',
#   array(['ARTICLE_2128', 'ARTICLE_2981', 'ARTICLE_2041', 'ARTICLE_0297',
#          'ARTICLE_2063'], dtype=object)],
#  ['USER_0897',
#   array(['ARTICLE_2126', 'ARTICLE_0445', 'ARTICLE_2052', 'ARTICLE_2473',
#          'ARTICLE_0226'], dtype=object)],
#  ['USER_0898',
#   array(['ARTICLE_0690', 'ARTICLE_2682', 'ARTICLE_0606', 'ARTICLE_0614',
#          'ARTICLE_0179'], dtype=object)],
#  ['USER_0899',
#   array(['ARTICLE_2570', 'ARTICLE_1159', 'ARTICLE_1562', 'ARTICLE_1568',
#          'ARTICLE_1152'], dtype=object)],
#  ['USER_0900',
#   array(['ARTICLE_1910', 'ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_1092',
#          'ARTICLE_1018'], dtype=object)],
#  ['USER_0901',
#   array(['ARTICLE_2008', 'ARTICLE_1192', 'ARTICLE_1624', 'ARTICLE_2485',
#          'ARTICLE_2017'], dtype=object)],
#  ['USER_0902',
#   array(['ARTICLE_1351', 'ARTICLE_1788', 'ARTICLE_2409', 'ARTICLE_1841',
#          'ARTICLE_0803'], dtype=object)],
#  ['USER_0903',
#   array(['ARTICLE_3007', 'ARTICLE_0294', 'ARTICLE_2274', 'ARTICLE_1447',
#          'ARTICLE_1980'], dtype=object)],
#  ['USER_0904',
#   array(['ARTICLE_1945', 'ARTICLE_2221', 'ARTICLE_1397', 'ARTICLE_2879',
#          'ARTICLE_0693'], dtype=object)],
#  ['USER_0905',
#   array(['ARTICLE_0868', 'ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_2879',
#          'ARTICLE_1285'], dtype=object)],
#  ['USER_0906',
#   array(['ARTICLE_0431', 'ARTICLE_0436', 'ARTICLE_0339', 'ARTICLE_1282',
#          'ARTICLE_2158'], dtype=object)],
#  ['USER_0907',
#   array(['ARTICLE_1744', 'ARTICLE_2028', 'ARTICLE_1577', 'ARTICLE_1257',
#          'ARTICLE_2853'], dtype=object)],
#  ['USER_0908',
#   array(['ARTICLE_2489', 'ARTICLE_2651', 'ARTICLE_2684', 'ARTICLE_0367',
#          'ARTICLE_2258'], dtype=object)],
#  ['USER_0909',
#   array(['ARTICLE_1841', 'ARTICLE_0931', 'ARTICLE_2782', 'ARTICLE_2529',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0910',
#   array(['ARTICLE_0610', 'ARTICLE_0971', 'ARTICLE_1106', 'ARTICLE_2454',
#          'ARTICLE_0086'], dtype=object)],
#  ['USER_0911',
#   array(['ARTICLE_1092', 'ARTICLE_2879', 'ARTICLE_0868', 'ARTICLE_2668',
#          'ARTICLE_0203'], dtype=object)],
#  ['USER_0912',
#   array(['ARTICLE_1351', 'ARTICLE_1788', 'ARTICLE_1841', 'ARTICLE_2879',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0913',
#   array(['ARTICLE_1910', 'ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1092',
#          'ARTICLE_0744'], dtype=object)],
#  ['USER_0914',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1788', 'ARTICLE_1018',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0915',
#   array(['ARTICLE_0926', 'ARTICLE_2409', 'ARTICLE_1788', 'ARTICLE_1982',
#          'ARTICLE_0445'], dtype=object)],
#  ['USER_0916',
#   array(['ARTICLE_0844', 'ARTICLE_1391', 'ARTICLE_0483', 'ARTICLE_1837',
#          'ARTICLE_0003'], dtype=object)],
#  ['USER_0917',
#   array(['ARTICLE_2118', 'ARTICLE_1601', 'ARTICLE_0610', 'ARTICLE_0968',
#          'ARTICLE_0086'], dtype=object)],
#  ['USER_0918',
#   array(['ARTICLE_2592', 'ARTICLE_2406', 'ARTICLE_2164', 'ARTICLE_1018',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0919',
#   array(['ARTICLE_1673', 'ARTICLE_1490', 'ARTICLE_1885', 'ARTICLE_1440',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0920',
#   array(['ARTICLE_2036', 'ARTICLE_1240', 'ARTICLE_0313', 'ARTICLE_0461',
#          'ARTICLE_2310'], dtype=object)],
#  ['USER_0921',
#   array(['ARTICLE_2931', 'ARTICLE_2439', 'ARTICLE_0849', 'ARTICLE_2698',
#          'ARTICLE_1295'], dtype=object)],
#  ['USER_0922',
#   array(['ARTICLE_0664', 'ARTICLE_0588', 'ARTICLE_0587', 'ARTICLE_0830',
#          'ARTICLE_2609'], dtype=object)],
#  ['USER_0923',
#   array(['ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_0968', 'ARTICLE_1092',
#          'ARTICLE_1252'], dtype=object)],
#  ['USER_0924',
#   array(['ARTICLE_2782', 'ARTICLE_1601', 'ARTICLE_2736', 'ARTICLE_0262',
#          'ARTICLE_1351'], dtype=object)],
#  ['USER_0925',
#   array(['ARTICLE_0682', 'ARTICLE_1621', 'ARTICLE_2434', 'ARTICLE_2276',
#          'ARTICLE_0085'], dtype=object)],
#  ['USER_0926',
#   array(['ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_1788',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0927',
#   array(['ARTICLE_1015', 'ARTICLE_1624', 'ARTICLE_1058', 'ARTICLE_2043',
#          'ARTICLE_1947'], dtype=object)],
#  ['USER_0928',
#   array(['ARTICLE_1697', 'ARTICLE_2229', 'ARTICLE_2634', 'ARTICLE_0448',
#          'ARTICLE_0569'], dtype=object)],
#  ['USER_0929',
#   array(['ARTICLE_0968', 'ARTICLE_1601', 'ARTICLE_2118', 'ARTICLE_1092',
#          'ARTICLE_1608'], dtype=object)],
#  ['USER_0930',
#   array(['ARTICLE_2879', 'ARTICLE_0431', 'ARTICLE_0508', 'ARTICLE_1092',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0931',
#   array(['ARTICLE_2512', 'ARTICLE_0730', 'ARTICLE_1178', 'ARTICLE_0079',
#          'ARTICLE_2516'], dtype=object)],
#  ['USER_0932',
#   array(['ARTICLE_0610', 'ARTICLE_0968', 'ARTICLE_2118', 'ARTICLE_1824',
#          'ARTICLE_0086'], dtype=object)],
#  ['USER_0933',
#   array(['ARTICLE_0069', 'ARTICLE_1563', 'ARTICLE_0372', 'ARTICLE_0670',
#          'ARTICLE_2568'], dtype=object)],
#  ['USER_0934',
#   array(['ARTICLE_2806', 'ARTICLE_2868', 'ARTICLE_1053', 'ARTICLE_0668',
#          'ARTICLE_2699'], dtype=object)],
#  ['USER_0935',
#   array(['ARTICLE_0867', 'ARTICLE_1474', 'ARTICLE_2879', 'ARTICLE_1624',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0936',
#   array(['ARTICLE_2409', 'ARTICLE_2879', 'ARTICLE_1788', 'ARTICLE_1982',
#          'ARTICLE_0712'], dtype=object)],
#  ['USER_0937',
#   array(['ARTICLE_1503', 'ARTICLE_0046', 'ARTICLE_2264', 'ARTICLE_1386',
#          'ARTICLE_0748'], dtype=object)],
#  ['USER_0938',
#   array(['ARTICLE_2660', 'ARTICLE_1108', 'ARTICLE_1159', 'ARTICLE_1384',
#          'ARTICLE_1498'], dtype=object)],
#  ['USER_0939',
#   array(['ARTICLE_2148', 'ARTICLE_0968', 'ARTICLE_1092', 'ARTICLE_0610',
#          'ARTICLE_0362'], dtype=object)],
#  ['USER_0940',
#   array(['ARTICLE_0038', 'ARTICLE_1108', 'ARTICLE_1159', 'ARTICLE_1498',
#          'ARTICLE_2843'], dtype=object)],
#  ['USER_0941',
#   array(['ARTICLE_0712', 'ARTICLE_2166', 'ARTICLE_2879', 'ARTICLE_1982',
#          'ARTICLE_2782'], dtype=object)],
#  ['USER_0942',
#   array(['ARTICLE_1624', 'ARTICLE_0038', 'ARTICLE_0789', 'ARTICLE_1108',
#          'ARTICLE_0793'], dtype=object)],
#  ['USER_0943',
#   array(['ARTICLE_2361', 'ARTICLE_1737', 'ARTICLE_0589', 'ARTICLE_0110',
#          'ARTICLE_1151'], dtype=object)],
#  ['USER_0944',
#   array(['ARTICLE_2592', 'ARTICLE_1644', 'ARTICLE_1018', 'ARTICLE_1910',
#          'ARTICLE_2879'], dtype=object)],
#  ['USER_0945',
#   array(['ARTICLE_1997', 'ARTICLE_0419', 'ARTICLE_1024', 'ARTICLE_2815',
#          'ARTICLE_2092'], dtype=object)],
#  ['USER_0946',
#   array(['ARTICLE_2140', 'ARTICLE_0085', 'ARTICLE_1351', 'ARTICLE_2409',
#          'ARTICLE_2434'], dtype=object)],
#  ['USER_0947',
#   array(['ARTICLE_0803', 'ARTICLE_2399', 'ARTICLE_0959', 'ARTICLE_1739',
#          'ARTICLE_0179'], dtype=object)],
#  ['USER_0948',
#   array(['ARTICLE_2879', 'ARTICLE_1982', 'ARTICLE_1092', 'ARTICLE_1910',
#          'ARTICLE_0958'], dtype=object)],
#  ['USER_0949',
#   array(['ARTICLE_2879', 'ARTICLE_1841', 'ARTICLE_2409', 'ARTICLE_1910',
#          'ARTICLE_1504'], dtype=object)],
#  ['USER_0950',
#   array(['ARTICLE_0780', 'ARTICLE_0107', 'ARTICLE_2305', 'ARTICLE_0427',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0951',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_0958',
#          'ARTICLE_2044'], dtype=object)],
#  ['USER_0952',
#   array(['ARTICLE_1351', 'ARTICLE_1891', 'ARTICLE_2879', 'ARTICLE_0028',
#          'ARTICLE_0445'], dtype=object)],
#  ['USER_0953',
#   array(['ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_0744', 'ARTICLE_2409',
#          'ARTICLE_0968'], dtype=object)],
#  ['USER_0954',
#   array(['ARTICLE_1624', 'ARTICLE_1159', 'ARTICLE_1108', 'ARTICLE_0061',
#          'ARTICLE_1498'], dtype=object)],
#  ['USER_0955',
#   array(['ARTICLE_1439', 'ARTICLE_0741', 'ARTICLE_0565', 'ARTICLE_1490',
#          'ARTICLE_0541'], dtype=object)],
#  ['USER_0956',
#   array(['ARTICLE_2879', 'ARTICLE_1092', 'ARTICLE_1982', 'ARTICLE_2409',
#          'ARTICLE_1252'], dtype=object)],
#  ['USER_0957',
#   array(['ARTICLE_1248', 'ARTICLE_2868', 'ARTICLE_1543', 'ARTICLE_0868',
#          'ARTICLE_1474'], dtype=object)],
#  ['USER_0958',
#   array(['ARTICLE_1126', 'ARTICLE_0674', 'ARTICLE_1166', 'ARTICLE_2941',
#          'ARTICLE_1737'], dtype=object)],
#  ['USER_0959',
#   array(['ARTICLE_2455', 'ARTICLE_0546', 'ARTICLE_1735', 'ARTICLE_0931',
#          'ARTICLE_2623'], dtype=object)],
#  ['USER_0960',
#   array(['ARTICLE_2879', 'ARTICLE_2668', 'ARTICLE_1824', 'ARTICLE_1982',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0962',
#   array(['ARTICLE_2912', 'ARTICLE_2968', 'ARTICLE_2868', 'ARTICLE_0217',
#          'ARTICLE_2587'], dtype=object)],
#  ['USER_0963',
#   array(['ARTICLE_0780', 'ARTICLE_1541', 'ARTICLE_0878', 'ARTICLE_1910',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0964',
#   array(['ARTICLE_2941', 'ARTICLE_2086', 'ARTICLE_0630', 'ARTICLE_0961',
#          'ARTICLE_1653'], dtype=object)],
#  ['USER_0965',
#   array(['ARTICLE_2203', 'ARTICLE_2592', 'ARTICLE_2879', 'ARTICLE_2406',
#          'ARTICLE_1018'], dtype=object)],
#  ['USER_0966',
#   array(['ARTICLE_1498', 'ARTICLE_0038', 'ARTICLE_2839', 'ARTICLE_1159',
#          'ARTICLE_1108'], dtype=object)],
#  ['USER_0967',
#   array(['ARTICLE_2422', 'ARTICLE_1449', 'ARTICLE_2873', 'ARTICLE_0532',
#          'ARTICLE_1940'], dtype=object)],
#  ['USER_0968',
#   array(['ARTICLE_0744', 'ARTICLE_1092', 'ARTICLE_2879', 'ARTICLE_1252',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0969',
#   array(['ARTICLE_1760', 'ARTICLE_0999', 'ARTICLE_0733', 'ARTICLE_0225',
#          'ARTICLE_0217'], dtype=object)],
#  ['USER_0970',
#   array(['ARTICLE_0064', 'ARTICLE_2467', 'ARTICLE_1015', 'ARTICLE_2820',
#          'ARTICLE_1046'], dtype=object)],
#  ['USER_0971',
#   array(['ARTICLE_2917', 'ARTICLE_1745', 'ARTICLE_2803', 'ARTICLE_0479',
#          'ARTICLE_2806'], dtype=object)],
#  ['USER_0972',
#   array(['ARTICLE_1601', 'ARTICLE_2148', 'ARTICLE_0968', 'ARTICLE_2021',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0973',
#   array(['ARTICLE_2140', 'ARTICLE_0615', 'ARTICLE_2208', 'ARTICLE_0085',
#          'ARTICLE_0268'], dtype=object)],
#  ['USER_0974',
#   array(['ARTICLE_0737', 'ARTICLE_2857', 'ARTICLE_0649', 'ARTICLE_2008',
#          'ARTICLE_1470'], dtype=object)],
#  ['USER_0975',
#   array(['ARTICLE_1815', 'ARTICLE_2140', 'ARTICLE_0085', 'ARTICLE_0667',
#          'ARTICLE_0285'], dtype=object)],
#  ['USER_0976',
#   array(['ARTICLE_2406', 'ARTICLE_0451', 'ARTICLE_0859', 'ARTICLE_0620',
#          'ARTICLE_1947'], dtype=object)],
#  ['USER_0977',
#   array(['ARTICLE_1881', 'ARTICLE_2045', 'ARTICLE_0476', 'ARTICLE_1302',
#          'ARTICLE_0712'], dtype=object)],
#  ['USER_0978',
#   array(['ARTICLE_0331', 'ARTICLE_1603', 'ARTICLE_0273', 'ARTICLE_1568',
#          'ARTICLE_1745'], dtype=object)],
#  ['USER_0979',
#   array(['ARTICLE_1413', 'ARTICLE_2519', 'ARTICLE_2126', 'ARTICLE_0445',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_0980',
#   array(['ARTICLE_2879', 'ARTICLE_1788', 'ARTICLE_0445', 'ARTICLE_1504',
#          'ARTICLE_1982'], dtype=object)],
#  ['USER_0981',
#   array(['ARTICLE_1624', 'ARTICLE_1118', 'ARTICLE_0038', 'ARTICLE_1159',
#          'ARTICLE_1108'], dtype=object)],
#  ['USER_0982',
#   array(['ARTICLE_0693', 'ARTICLE_0436', 'ARTICLE_2045', 'ARTICLE_2221',
#          'ARTICLE_2158'], dtype=object)],
#  ['USER_0983',
#   array(['ARTICLE_1636', 'ARTICLE_1305', 'ARTICLE_0732', 'ARTICLE_2049',
#          'ARTICLE_0084'], dtype=object)],
#  ['USER_0984',
#   array(['ARTICLE_1793', 'ARTICLE_2999', 'ARTICLE_2933', 'ARTICLE_0699',
#          'ARTICLE_1023'], dtype=object)],
#  ['USER_0985',
#   array(['ARTICLE_2197', 'ARTICLE_2409', 'ARTICLE_0966', 'ARTICLE_1092',
#          'ARTICLE_2158'], dtype=object)],
#  ['USER_0986',
#   array(['ARTICLE_1013', 'ARTICLE_1624', 'ARTICLE_0411', 'ARTICLE_0830',
#          'ARTICLE_2651'], dtype=object)],
#  ['USER_0987',
#   array(['ARTICLE_2782', 'ARTICLE_2576', 'ARTICLE_2879', 'ARTICLE_1982',
#          'ARTICLE_1504'], dtype=object)],
#  ['USER_0988',
#   array(['ARTICLE_0133', 'ARTICLE_1568', 'ARTICLE_0815', 'ARTICLE_0488',
#          'ARTICLE_0812'], dtype=object)],
#  ['USER_0989',
#   array(['ARTICLE_1092', 'ARTICLE_0958', 'ARTICLE_2879', 'ARTICLE_0203',
#          'ARTICLE_2668'], dtype=object)],
#  ['USER_0990',
#   array(['ARTICLE_2259', 'ARTICLE_2617', 'ARTICLE_0653', 'ARTICLE_0733',
#          'ARTICLE_0446'], dtype=object)],
#  ['USER_0991',
#   array(['ARTICLE_2868', 'ARTICLE_1740', 'ARTICLE_1772', 'ARTICLE_1883',
#          'ARTICLE_2991'], dtype=object)],
#  ['USER_0992',
#   array(['ARTICLE_0226', 'ARTICLE_2651', 'ARTICLE_1257', 'ARTICLE_2684',
#          'ARTICLE_2258'], dtype=object)],
#  ['USER_0993',
#   array(['ARTICLE_2660', 'ARTICLE_0033', 'ARTICLE_1657', 'ARTICLE_0276',
#          'ARTICLE_0684'], dtype=object)],
#  ['USER_0994',
#   array(['ARTICLE_2409', 'ARTICLE_2782', 'ARTICLE_0868', 'ARTICLE_2879',
#          'ARTICLE_2129'], dtype=object)],
#  ['USER_0995',
#   array(['ARTICLE_1841', 'ARTICLE_2879', 'ARTICLE_1018', 'ARTICLE_1252',
#          'ARTICLE_2409'], dtype=object)],
#  ['USER_0996',
#   array(['ARTICLE_1092', 'ARTICLE_2879', 'ARTICLE_2782', 'ARTICLE_2409',
#          'ARTICLE_1252'], dtype=object)],
#  ['USER_0997',
#   array(['ARTICLE_2489', 'ARTICLE_0255', 'ARTICLE_2246', 'ARTICLE_2653',
#          'ARTICLE_2743'], dtype=object)],
#  ['USER_0998',
#   array(['ARTICLE_2879', 'ARTICLE_2409', 'ARTICLE_1841', 'ARTICLE_1788',
#          'ARTICLE_0744'], dtype=object)],
#  ['USER_0999',
#   array(['ARTICLE_2660', 'ARTICLE_2283', 'ARTICLE_1434', 'ARTICLE_2785',
#          'ARTICLE_0783'], dtype=object)],
#  ['USER_1000',
#   array(['ARTICLE_2782', 'ARTICLE_1258', 'ARTICLE_2879', 'ARTICLE_1982',
#          'ARTICLE_1092'], dtype=object)],
#  ['USER_1001',
#   array(['ARTICLE_2616', 'ARTICLE_2772', 'ARTICLE_1007', 'ARTICLE_0750',
#          'ARTICLE_1639'], dtype=object)],
#  ['USER_1002',
#   array(['ARTICLE_0693', 'ARTICLE_1397', 'ARTICLE_2221', 'ARTICLE_3006',
#          'ARTICLE_2998'], dtype=object)],
#  ['USER_1003',
#   array(['ARTICLE_0262', 'ARTICLE_0887', 'ARTICLE_1470', 'ARTICLE_2474',
#          'ARTICLE_1190'], dtype=object)],
#  ['USER_1004',
#   array(['ARTICLE_0364', 'ARTICLE_0062', 'ARTICLE_1600', 'ARTICLE_1200',
#          'ARTICLE_2517'], dtype=object)],
#  ['USER_1005',
#   array(['ARTICLE_1351', 'ARTICLE_2409', 'ARTICLE_1092', 'ARTICLE_2879',
#          'ARTICLE_0445'], dtype=object)],
#  ...]

# %%
recommendations = pd.DataFrame(recommendations, columns=['userID', 'articleID'])

# %%
recommendations = recommendations.explode('articleID').reset_index(drop=True)

# %%
submission = recommendations.to_csv(data_path + 'submission_v2.csv')

# %%
submission

# %%
data_path
# Out:
# '/content/drive/MyDrive/데이콘/기사추천시스템/open/'

# %%
# word2vec

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import pandas as pd
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

# 예시 데이터프레임 생성
data = article_info


# 텍스트 전처리 함수 정의
def preprocess_text(text):
    # 소문자 변환
    text = text.lower()
    # 구두점 제거
    text = text.translate(str.maketrans('', '', string.punctuation))
    # 불용어 제거 (예시로 nltk의 불용어 사용)
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text)
    tokens = [token for token in tokens if token not in stop_words]
    return tokens

# 텍스트 전처리 및 단어 리스트 생성
processed_texts = [preprocess_text(text) for text in article_info['Content']]

# Word2Vec 모델 학습
model = Word2Vec(processed_texts, vector_size=100, window=5, min_count=1, sg=1)

# 기사 벡터화
# 기사 제목 벡터화

# 기사 벡터화 및 유사도 계산 예시
def calculate_article_similarity(article1, article2, model):
    vec1 = model.wv[article1]
    vec2 = model.wv[article2]
    similarity = cosine_similarity([vec1], [vec2])[0][0]
    return similarity

# 예시: ARTICLE_2441과 ARTICLE_1270의 유사도 계산
similarity_score = calculate_article_similarity('article', 'article', model)
print(f"Similarity between ARTICLE_2441 and ARTICLE_1270: {similarity_score}")


# 개인별 기사 추천 함수 정의
def recommend_articles(user_id, model, article_info, top_n=5):
    # 사용자가 읽은 기사ID 목록
    read_articles = article_info[article_info['userID'] == user_id]['articleID'].tolist()

    # 사용자가 읽지 않은 기사ID 목록
    unread_articles = article_info[~article_info['articleID'].isin(read_articles)]['articleID'].unique()

    # 사용자가 읽지 않은 기사들과의 유사도 계산
    similarities = []
    for article_id in unread_articles:
        similarity = 0
        for read_article_id in read_articles:
            similarity += calculate_article_similarity(read_article_id, article_id, model)
        similarity /= len(read_articles)  # 평균 유사도 계산
        similarities.append((article_id, similarity))

    # 유사도가 높은 순서로 정렬
    similarities.sort(key=lambda x: x[1], reverse=True)

    # 상위 top_n개 기사 추천
    recommended_articles = similarities[:top_n]

    return recommended_articles
# Out:
# Similarity between ARTICLE_2441 and ARTICLE_1270: 1.0

# %%
recommendations = recommend_articles('USER_0000', model, article_info)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-135-6d071fdac4e5> in <cell line: 1>()
# ----> 1 recommendations = recommend_articles('USER_0000', model, article_info)
#
# <ipython-input-134-8fc083b32692> in recommend_articles(user_id, model, article_info, top_n)
#      56         similarity = 0
#      57         for read_article_id in read_articles:
# ---> 58             similarity += calculate_article_similarity(read_article_id, article_id, model)
#      59         similarity /= len(read_articles)  # 평균 유사도 계산
#      60         similarities.append((article_id, similarity))
#
# <ipython-input-134-8fc083b32692> in calculate_article_similarity(article1, article2, model)
#      33 # 기사 벡터화 및 유사도 계산 예시
#      34 def calculate_article_similarity(article1, article2, model):
# ---> 35     vec1 = model.wv[article1]
#      36     vec2 = model.wv[article2]
#      37     similarity = cosine_similarity([vec1], [vec2])[0][0]
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in __getitem__(self, key_or_keys)
#     401         """
#     402         if isinstance(key_or_keys, _KEY_TYPES):
# --> 403             return self.get_vector(key_or_keys)
#     404
#     405         return vstack([self.get_vector(key) for key in key_or_keys])
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in get_vector(self, key, norm)
#     444
#     445         """
# --> 446         index = self.get_index(key)
#     447         if norm:
#     448             self.fill_norms()
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in get_index(self, key, default)
#     418             return default
#     419         else:
# --> 420             raise KeyError(f"Key '{key}' not present")
#     421
#     422     def get_vector(self, key, norm=False):
#
# KeyError: "Key 'ARTICLE_1345' not present"
